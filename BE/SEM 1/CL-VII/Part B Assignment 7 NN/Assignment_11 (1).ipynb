# %% [markdown]
# # MLA Lab 6  Artificial Neural Network for Machine Learning
# ### 43308
# ### Ayan Gadpal
# **Aim: Creating & Visualizing Neural Network for the given data. (Using Python)(Use Cancer Dataset)** <br>
# Simply put, an ANN represents interconnected input and output units in which each connection has an associated weight. During the learning phase, the network learns by adjusting these weights in order to be able to predict the correct class for input data.

# %%
import torch
import numpy as np
import pandas as pd
from torch.autograd import Variable
import torch.nn.functional as F
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
import os

# %% [markdown]
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image.
# n the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
# <br> TASK Correctly classify whether the tumor is benign or malignant.

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
cols = data.columns
x_data = data[cols[2:-1]]
print(len(cols))
x_data.head()
# Out:
# 33
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
y_data = data[cols[1]]
le = LabelEncoder()
y_data = np.array(le.fit_transform(y_data))
y_data[:5], le.classes_
# Out:
# (array([1, 1, 1, 1, 1]), array(['B', 'M'], dtype=object))

# %%
y_data.shape, x_data.values.shape
# Out:
# ((569,), (569, 30))

# %%
x_data = Variable(torch.from_numpy(x_data.values))
y_data = Variable(torch.from_numpy(y_data))

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.l1 = torch.nn.Linear(30,16)
        self.l2 = torch.nn.Linear(16,4)
        self.l3 = torch.nn.Linear(4,1)
        
        self.sigmoid = torch.nn.Sigmoid()
        
    def forward(self, x):
        out1 = self.sigmoid(self.l1(x)) 
        out2 = self.sigmoid(self.l2(out1))
        y_pred = self.sigmoid(self.l3(out2))
        return y_pred
    
model = Model()

# %%
x_data.float().size(), y_data.float().size()
# Out:
# ((569, 30), (569,))

# %%
criterion = torch.nn.BCELoss(reduction='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epochs in range(500):
    y_pred = model(x_data.float())
    loss = criterion(y_pred, y_data.view(-1,1).float())
    print('Epoch',epochs,'Loss:',loss.item(), '- Pred:', y_pred.data[0])
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch 0 Loss: 376.59124755859375 - Pred: tensor([0.3420])
# Epoch 1 Loss: 376.39971923828125 - Pred: tensor([0.3432])
# Epoch 2 Loss: 376.1672668457031 - Pred: tensor([0.3444])
# Epoch 3 Loss: 375.89788818359375 - Pred: tensor([0.3456])
# Epoch 4 Loss: 375.593994140625 - Pred: tensor([0.3468])
# Epoch 5 Loss: 375.26361083984375 - Pred: tensor([0.3479])
# Epoch 6 Loss: 374.93707275390625 - Pred: tensor([0.3491])
# Epoch 7 Loss: 374.6343688964844 - Pred: tensor([0.3503])
# Epoch 8 Loss: 374.3460693359375 - Pred: tensor([0.3514])
# Epoch 9 Loss: 374.0801086425781 - Pred: tensor([0.3526])
# Epoch 10 Loss: 373.851806640625 - Pred: tensor([0.3537])
# Epoch 11 Loss: 373.6623229980469 - Pred: tensor([0.3548])
# Epoch 12 Loss: 373.5060119628906 - Pred: tensor([0.3560])
# Epoch 13 Loss: 373.386962890625 - Pred: tensor([0.3571])
# Epoch 14 Loss: 373.30279541015625 - Pred: tensor([0.3581])
# Epoch 15 Loss: 373.2515869140625 - Pred: tensor([0.3592])
# Epoch 16 Loss: 373.2099609375 - Pred: tensor([0.3602])
# Epoch 17 Loss: 373.1726379394531 - Pred: tensor([0.3612])
# Epoch 18 Loss: 373.1419677734375 - Pred: tensor([0.3622])
# Epoch 19 Loss: 373.1011657714844 - Pred: tensor([0.3632])
# Epoch 20 Loss: 373.04205322265625 - Pred: tensor([0.3641])
# Epoch 21 Loss: 372.9678039550781 - Pred: tensor([0.3650])
# Epoch 22 Loss: 372.8834228515625 - Pred: tensor([0.3659])
# Epoch 23 Loss: 372.79229736328125 - Pred: tensor([0.3667])
# Epoch 24 Loss: 372.69775390625 - Pred: tensor([0.3675])
# Epoch 25 Loss: 372.6063232421875 - Pred: tensor([0.3683])
# Epoch 26 Loss: 372.52093505859375 - Pred: tensor([0.3690])
# Epoch 27 Loss: 372.4320983886719 - Pred: tensor([0.3698])
# Epoch 28 Loss: 372.3350524902344 - Pred: tensor([0.3704])
# Epoch 29 Loss: 372.2356872558594 - Pred: tensor([0.3711])
# Epoch 30 Loss: 372.1446838378906 - Pred: tensor([0.3716])
# Epoch 31 Loss: 372.0660400390625 - Pred: tensor([0.3722])
# Epoch 32 Loss: 371.99517822265625 - Pred: tensor([0.3727])
# Epoch 33 Loss: 371.9261169433594 - Pred: tensor([0.3732])
# Epoch 34 Loss: 371.85174560546875 - Pred: tensor([0.3737])
# Epoch 35 Loss: 371.76568603515625 - Pred: tensor([0.3741])
# Epoch 36 Loss: 371.66845703125 - Pred: tensor([0.3745])
# Epoch 37 Loss: 371.55712890625 - Pred: tensor([0.3748])
# Epoch 38 Loss: 371.4214782714844 - Pred: tensor([0.3752])
# Epoch 39 Loss: 371.2489318847656 - Pred: tensor([0.3755])
# Epoch 40 Loss: 371.0333251953125 - Pred: tensor([0.3757])
# Epoch 41 Loss: 370.778564453125 - Pred: tensor([0.3760])
# Epoch 42 Loss: 370.506591796875 - Pred: tensor([0.3762])
# Epoch 43 Loss: 370.226318359375 - Pred: tensor([0.3765])
# Epoch 44 Loss: 369.9737548828125 - Pred: tensor([0.3767])
# Epoch 45 Loss: 369.7755126953125 - Pred: tensor([0.3769])
# Epoch 46 Loss: 369.6351013183594 - Pred: tensor([0.3771])
# Epoch 47 Loss: 369.54052734375 - Pred: tensor([0.3773])
# Epoch 48 Loss: 369.4627990722656 - Pred: tensor([0.3775])
# Epoch 49 Loss: 369.3802490234375 - Pred: tensor([0.3778])
# Epoch 50 Loss: 369.2587890625 - Pred: tensor([0.3780])
# Epoch 51 Loss: 369.09521484375 - Pred: tensor([0.3782])
# Epoch 52 Loss: 368.8996276855469 - Pred: tensor([0.3784])
# Epoch 53 Loss: 368.6951599121094 - Pred: tensor([0.3787])
# Epoch 54 Loss: 368.494140625 - Pred: tensor([0.3789])
# Epoch 55 Loss: 368.3017272949219 - Pred: tensor([0.3791])
# Epoch 56 Loss: 368.1275939941406 - Pred: tensor([0.3793])
# Epoch 57 Loss: 367.9797058105469 - Pred: tensor([0.3796])
# Epoch 58 Loss: 367.8449401855469 - Pred: tensor([0.3798])
# Epoch 59 Loss: 367.7093811035156 - Pred: tensor([0.3800])
# Epoch 60 Loss: 367.5639343261719 - Pred: tensor([0.3803])
# Epoch 61 Loss: 367.4036865234375 - Pred: tensor([0.3805])
# Epoch 62 Loss: 367.22882080078125 - Pred: tensor([0.3807])
# Epoch 63 Loss: 367.04364013671875 - Pred: tensor([0.3809])
# Epoch 64 Loss: 366.8546142578125 - Pred: tensor([0.3811])
# Epoch 65 Loss: 366.6683044433594 - Pred: tensor([0.3814])
# Epoch 66 Loss: 366.4913024902344 - Pred: tensor([0.3816])
# Epoch 67 Loss: 366.3260192871094 - Pred: tensor([0.3818])
# Epoch 68 Loss: 366.1687316894531 - Pred: tensor([0.3820])
# Epoch 69 Loss: 366.0118408203125 - Pred: tensor([0.3822])
# Epoch 70 Loss: 365.8470458984375 - Pred: tensor([0.3825])
# Epoch 71 Loss: 365.671630859375 - Pred: tensor([0.3827])
# Epoch 72 Loss: 365.4898986816406 - Pred: tensor([0.3829])
# Epoch 73 Loss: 365.3086242675781 - Pred: tensor([0.3832])
# Epoch 74 Loss: 365.1318664550781 - Pred: tensor([0.3834])
# Epoch 75 Loss: 364.9609069824219 - Pred: tensor([0.3836])
# Epoch 76 Loss: 364.79425048828125 - Pred: tensor([0.3839])
# Epoch 77 Loss: 364.62835693359375 - Pred: tensor([0.3841])
# Epoch 78 Loss: 364.46002197265625 - Pred: tensor([0.3843])
# Epoch 79 Loss: 364.2879943847656 - Pred: tensor([0.3845])
# Epoch 80 Loss: 364.1127624511719 - Pred: tensor([0.3848])
# Epoch 81 Loss: 363.9362487792969 - Pred: tensor([0.3850])
# Epoch 82 Loss: 363.76080322265625 - Pred: tensor([0.3852])
# Epoch 83 Loss: 363.5880432128906 - Pred: tensor([0.3855])
# Epoch 84 Loss: 363.4178466796875 - Pred: tensor([0.3857])
# Epoch 85 Loss: 363.24847412109375 - Pred: tensor([0.3859])
# Epoch 86 Loss: 363.0780334472656 - Pred: tensor([0.3861])
# Epoch 87 Loss: 362.905517578125 - Pred: tensor([0.3864])
# Epoch 88 Loss: 362.7311096191406 - Pred: tensor([0.3866])
# Epoch 89 Loss: 362.5560302734375 - Pred: tensor([0.3868])
# Epoch 90 Loss: 362.381591796875 - Pred: tensor([0.3871])
# Epoch 91 Loss: 362.20843505859375 - Pred: tensor([0.3873])
# Epoch 92 Loss: 362.03619384765625 - Pred: tensor([0.3875])
# Epoch 93 Loss: 361.86370849609375 - Pred: tensor([0.3878])
# Epoch 94 Loss: 361.69012451171875 - Pred: tensor([0.3880])
# Epoch 95 Loss: 361.5151672363281 - Pred: tensor([0.3882])
# Epoch 96 Loss: 361.3392639160156 - Pred: tensor([0.3884])
# Epoch 97 Loss: 361.16302490234375 - Pred: tensor([0.3887])
# Epoch 98 Loss: 360.98675537109375 - Pred: tensor([0.3889])
# Epoch 99 Loss: 360.80975341796875 - Pred: tensor([0.3891])
# Epoch 100 Loss: 360.6297607421875 - Pred: tensor([0.3893])
# Epoch 101 Loss: 360.44110107421875 - Pred: tensor([0.3896])
# Epoch 102 Loss: 360.2314453125 - Pred: tensor([0.3898])
# Epoch 103 Loss: 359.976806640625 - Pred: tensor([0.3900])
# Epoch 104 Loss: 359.6380615234375 - Pred: tensor([0.3903])
# Epoch 105 Loss: 359.1713562011719 - Pred: tensor([0.3905])
# Epoch 106 Loss: 358.59088134765625 - Pred: tensor([0.3908])
# Epoch 107 Loss: 358.06158447265625 - Pred: tensor([0.3911])
# Epoch 108 Loss: 357.8539123535156 - Pred: tensor([0.3914])
# Epoch 109 Loss: 357.8246765136719 - Pred: tensor([0.3918])
# Epoch 110 Loss: 357.70819091796875 - Pred: tensor([0.3921])
# Epoch 111 Loss: 357.4544982910156 - Pred: tensor([0.3925])
# Epoch 112 Loss: 357.0927734375 - Pred: tensor([0.3929])
# Epoch 113 Loss: 356.6894226074219 - Pred: tensor([0.3933])
# Epoch 114 Loss: 356.319091796875 - Pred: tensor([0.3938])
# Epoch 115 Loss: 356.06207275390625 - Pred: tensor([0.3942])
# Epoch 116 Loss: 355.90679931640625 - Pred: tensor([0.3946])
# Epoch 117 Loss: 355.7197265625 - Pred: tensor([0.3950])
# Epoch 118 Loss: 355.4432678222656 - Pred: tensor([0.3954])
# Epoch 119 Loss: 355.09674072265625 - Pred: tensor([0.3958])
# Epoch 120 Loss: 354.74066162109375 - Pred: tensor([0.3962])
# Epoch 121 Loss: 354.45135498046875 - Pred: tensor([0.3966])
# Epoch 122 Loss: 354.22723388671875 - Pred: tensor([0.3970])
# Epoch 123 Loss: 354.00921630859375 - Pred: tensor([0.3974])
# Epoch 124 Loss: 353.7503967285156 - Pred: tensor([0.3978])
# Epoch 125 Loss: 353.4447937011719 - Pred: tensor([0.3982])
# Epoch 126 Loss: 353.12054443359375 - Pred: tensor([0.3986])
# Epoch 127 Loss: 352.817138671875 - Pred: tensor([0.3989])
# Epoch 128 Loss: 352.5645446777344 - Pred: tensor([0.3993])
# Epoch 129 Loss: 352.326171875 - Pred: tensor([0.3997])
# Epoch 130 Loss: 352.0615539550781 - Pred: tensor([0.4001])
# Epoch 131 Loss: 351.76513671875 - Pred: tensor([0.4004])
# Epoch 132 Loss: 351.4581298828125 - Pred: tensor([0.4008])
# Epoch 133 Loss: 351.1699523925781 - Pred: tensor([0.4011])
# Epoch 134 Loss: 350.91107177734375 - Pred: tensor([0.4014])
# Epoch 135 Loss: 350.6543273925781 - Pred: tensor([0.4018])
# Epoch 136 Loss: 350.3743896484375 - Pred: tensor([0.4021])
# Epoch 137 Loss: 350.076416015625 - Pred: tensor([0.4025])
# Epoch 138 Loss: 349.7856750488281 - Pred: tensor([0.4028])
# Epoch 139 Loss: 349.50958251953125 - Pred: tensor([0.4032])
# Epoch 140 Loss: 349.2326965332031 - Pred: tensor([0.4035])
# Epoch 141 Loss: 348.9515075683594 - Pred: tensor([0.4038])
# Epoch 142 Loss: 348.6673278808594 - Pred: tensor([0.4042])
# Epoch 143 Loss: 348.3762512207031 - Pred: tensor([0.4045])
# Epoch 144 Loss: 348.0863952636719 - Pred: tensor([0.4048])
# Epoch 145 Loss: 347.80517578125 - Pred: tensor([0.4052])
# Epoch 146 Loss: 347.5308837890625 - Pred: tensor([0.4055])
# Epoch 147 Loss: 347.2544250488281 - Pred: tensor([0.4058])
# Epoch 148 Loss: 346.9700927734375 - Pred: tensor([0.4062])
# Epoch 149 Loss: 346.6822204589844 - Pred: tensor([0.4066])
# Epoch 150 Loss: 346.3977966308594 - Pred: tensor([0.4069])
# Epoch 151 Loss: 346.11773681640625 - Pred: tensor([0.4073])
# Epoch 152 Loss: 345.838623046875 - Pred: tensor([0.4077])
# Epoch 153 Loss: 345.55694580078125 - Pred: tensor([0.4080])
# Epoch 154 Loss: 345.2720947265625 - Pred: tensor([0.4084])
# Epoch 155 Loss: 344.9858093261719 - Pred: tensor([0.4088])
# Epoch 156 Loss: 344.7000427246094 - Pred: tensor([0.4092])
# Epoch 157 Loss: 344.4154357910156 - Pred: tensor([0.4096])
# Epoch 158 Loss: 344.13128662109375 - Pred: tensor([0.4100])
# Epoch 159 Loss: 343.84625244140625 - Pred: tensor([0.4103])
# Epoch 160 Loss: 343.55950927734375 - Pred: tensor([0.4107])
# Epoch 161 Loss: 343.2714538574219 - Pred: tensor([0.4111])
# Epoch 162 Loss: 342.9825744628906 - Pred: tensor([0.4116])
# Epoch 163 Loss: 342.6933898925781 - Pred: tensor([0.4120])
# Epoch 164 Loss: 342.4039001464844 - Pred: tensor([0.4124])
# Epoch 165 Loss: 342.1137390136719 - Pred: tensor([0.4128])
# Epoch 166 Loss: 341.8226013183594 - Pred: tensor([0.4132])
# Epoch 167 Loss: 341.5301818847656 - Pred: tensor([0.4136])
# Epoch 168 Loss: 341.2364196777344 - Pred: tensor([0.4140])
# Epoch 169 Loss: 340.9411926269531 - Pred: tensor([0.4144])
# Epoch 170 Loss: 340.64422607421875 - Pred: tensor([0.4148])
# Epoch 171 Loss: 340.3445739746094 - Pred: tensor([0.4152])
# Epoch 172 Loss: 340.03973388671875 - Pred: tensor([0.4156])
# Epoch 173 Loss: 339.7294006347656 - Pred: tensor([0.4160])
# Epoch 174 Loss: 339.4245910644531 - Pred: tensor([0.4164])
# Epoch 175 Loss: 339.12164306640625 - Pred: tensor([0.4168])
# Epoch 176 Loss: 338.81158447265625 - Pred: tensor([0.4171])
# Epoch 177 Loss: 338.5009765625 - Pred: tensor([0.4175])
# Epoch 178 Loss: 338.1951599121094 - Pred: tensor([0.4179])
# Epoch 179 Loss: 337.8896789550781 - Pred: tensor([0.4183])
# Epoch 180 Loss: 337.5794982910156 - Pred: tensor([0.4187])
# Epoch 181 Loss: 337.2659912109375 - Pred: tensor([0.4191])
# Epoch 182 Loss: 336.9547424316406 - Pred: tensor([0.4195])
# Epoch 183 Loss: 336.6453552246094 - Pred: tensor([0.4199])
# Epoch 184 Loss: 336.3322448730469 - Pred: tensor([0.4203])
# Epoch 185 Loss: 336.01629638671875 - Pred: tensor([0.4207])
# Epoch 186 Loss: 335.70159912109375 - Pred: tensor([0.4211])
# Epoch 187 Loss: 335.38800048828125 - Pred: tensor([0.4215])
# Epoch 188 Loss: 335.07281494140625 - Pred: tensor([0.4219])
# Epoch 189 Loss: 334.75653076171875 - Pred: tensor([0.4223])
# Epoch 190 Loss: 334.4400329589844 - Pred: tensor([0.4228])
# Epoch 191 Loss: 334.123291015625 - Pred: tensor([0.4232])
# Epoch 192 Loss: 333.807373046875 - Pred: tensor([0.4237])
# Epoch 193 Loss: 333.490966796875 - Pred: tensor([0.4241])
# Epoch 194 Loss: 333.1728210449219 - Pred: tensor([0.4246])
# Epoch 195 Loss: 332.8552551269531 - Pred: tensor([0.4251])
# Epoch 196 Loss: 332.538818359375 - Pred: tensor([0.4255])
# Epoch 197 Loss: 332.2212219238281 - Pred: tensor([0.4260])
# Epoch 198 Loss: 331.90277099609375 - Pred: tensor([0.4265])
# Epoch 199 Loss: 331.58489990234375 - Pred: tensor([0.4270])
# Epoch 200 Loss: 331.26708984375 - Pred: tensor([0.4275])
# Epoch 201 Loss: 330.94873046875 - Pred: tensor([0.4280])
# Epoch 202 Loss: 330.6300354003906 - Pred: tensor([0.4285])
# Epoch 203 Loss: 330.3111267089844 - Pred: tensor([0.4291])
# Epoch 204 Loss: 329.9921569824219 - Pred: tensor([0.4296])
# Epoch 205 Loss: 329.673095703125 - Pred: tensor([0.4301])
# Epoch 206 Loss: 329.3533935546875 - Pred: tensor([0.4306])
# Epoch 207 Loss: 329.03326416015625 - Pred: tensor([0.4311])
# Epoch 208 Loss: 328.7132873535156 - Pred: tensor([0.4316])
# Epoch 209 Loss: 328.3929748535156 - Pred: tensor([0.4321])
# Epoch 210 Loss: 328.07196044921875 - Pred: tensor([0.4327])
# Epoch 211 Loss: 327.7506103515625 - Pred: tensor([0.4332])
# Epoch 212 Loss: 327.42919921875 - Pred: tensor([0.4337])
# Epoch 213 Loss: 327.1072998046875 - Pred: tensor([0.4342])
# Epoch 214 Loss: 326.78485107421875 - Pred: tensor([0.4347])
# Epoch 215 Loss: 326.4620666503906 - Pred: tensor([0.4352])
# Epoch 216 Loss: 326.1390075683594 - Pred: tensor([0.4358])
# Epoch 217 Loss: 325.8154602050781 - Pred: tensor([0.4363])
# Epoch 218 Loss: 325.4914245605469 - Pred: tensor([0.4368])
# Epoch 219 Loss: 325.1669616699219 - Pred: tensor([0.4373])
# Epoch 220 Loss: 324.8421325683594 - Pred: tensor([0.4378])
# Epoch 221 Loss: 324.516845703125 - Pred: tensor([0.4383])
# Epoch 222 Loss: 324.1910705566406 - Pred: tensor([0.4389])
# Epoch 223 Loss: 323.8648986816406 - Pred: tensor([0.4394])
# Epoch 224 Loss: 323.5382080078125 - Pred: tensor([0.4399])
# Epoch 225 Loss: 323.2111511230469 - Pred: tensor([0.4404])
# Epoch 226 Loss: 322.883544921875 - Pred: tensor([0.4410])
# Epoch 227 Loss: 322.5555114746094 - Pred: tensor([0.4415])
# Epoch 228 Loss: 322.22705078125 - Pred: tensor([0.4421])
# Epoch 229 Loss: 321.8980712890625 - Pred: tensor([0.4426])
# Epoch 230 Loss: 321.568603515625 - Pred: tensor([0.4431])
# Epoch 231 Loss: 321.2386474609375 - Pred: tensor([0.4437])
# Epoch 232 Loss: 320.9082946777344 - Pred: tensor([0.4442])
# Epoch 233 Loss: 320.57745361328125 - Pred: tensor([0.4448])
# Epoch 234 Loss: 320.2460632324219 - Pred: tensor([0.4453])
# Epoch 235 Loss: 319.91424560546875 - Pred: tensor([0.4459])
# Epoch 236 Loss: 319.58197021484375 - Pred: tensor([0.4465])
# Epoch 237 Loss: 319.2491760253906 - Pred: tensor([0.4470])
# Epoch 238 Loss: 318.91583251953125 - Pred: tensor([0.4476])
# Epoch 239 Loss: 318.5820617675781 - Pred: tensor([0.4482])
# Epoch 240 Loss: 318.247802734375 - Pred: tensor([0.4487])
# Epoch 241 Loss: 317.9129638671875 - Pred: tensor([0.4493])
# Epoch 242 Loss: 317.5776672363281 - Pred: tensor([0.4499])
# Epoch 243 Loss: 317.24188232421875 - Pred: tensor([0.4505])
# Epoch 244 Loss: 316.90557861328125 - Pred: tensor([0.4511])
# Epoch 245 Loss: 316.5687255859375 - Pred: tensor([0.4516])
# Epoch 246 Loss: 316.2313537597656 - Pred: tensor([0.4522])
# Epoch 247 Loss: 315.89349365234375 - Pred: tensor([0.4528])
# Epoch 248 Loss: 315.5550537109375 - Pred: tensor([0.4534])
# Epoch 249 Loss: 315.216064453125 - Pred: tensor([0.4540])
# Epoch 250 Loss: 314.8765869140625 - Pred: tensor([0.4546])
# Epoch 251 Loss: 314.5365295410156 - Pred: tensor([0.4552])
# Epoch 252 Loss: 314.1958923339844 - Pred: tensor([0.4558])
# Epoch 253 Loss: 313.8546447753906 - Pred: tensor([0.4564])
# Epoch 254 Loss: 313.51287841796875 - Pred: tensor([0.4570])
# Epoch 255 Loss: 313.1705627441406 - Pred: tensor([0.4576])
# Epoch 256 Loss: 312.82757568359375 - Pred: tensor([0.4582])
# Epoch 257 Loss: 312.4840087890625 - Pred: tensor([0.4589])
# Epoch 258 Loss: 312.13983154296875 - Pred: tensor([0.4595])
# Epoch 259 Loss: 311.7950439453125 - Pred: tensor([0.4601])
# Epoch 260 Loss: 311.4496154785156 - Pred: tensor([0.4607])
# Epoch 261 Loss: 311.1035461425781 - Pred: tensor([0.4614])
# Epoch 262 Loss: 310.7568054199219 - Pred: tensor([0.4620])
# Epoch 263 Loss: 310.40948486328125 - Pred: tensor([0.4626])
# Epoch 264 Loss: 310.0614013671875 - Pred: tensor([0.4633])
# Epoch 265 Loss: 309.7126770019531 - Pred: tensor([0.4639])
# Epoch 266 Loss: 309.3633117675781 - Pred: tensor([0.4646])
# Epoch 267 Loss: 309.01318359375 - Pred: tensor([0.4652])
# Epoch 268 Loss: 308.6623840332031 - Pred: tensor([0.4659])
# Epoch 269 Loss: 308.31085205078125 - Pred: tensor([0.4665])
# Epoch 270 Loss: 307.9585876464844 - Pred: tensor([0.4672])
# Epoch 271 Loss: 307.6056213378906 - Pred: tensor([0.4679])
# Epoch 272 Loss: 307.25189208984375 - Pred: tensor([0.4685])
# Epoch 273 Loss: 306.8973693847656 - Pred: tensor([0.4692])
# Epoch 274 Loss: 306.5421142578125 - Pred: tensor([0.4699])
# Epoch 275 Loss: 306.18609619140625 - Pred: tensor([0.4706])
# Epoch 276 Loss: 305.82928466796875 - Pred: tensor([0.4713])
# Epoch 277 Loss: 305.4716796875 - Pred: tensor([0.4720])
# Epoch 278 Loss: 305.11328125 - Pred: tensor([0.4727])
# Epoch 279 Loss: 304.7540588378906 - Pred: tensor([0.4733])
# Epoch 280 Loss: 304.39404296875 - Pred: tensor([0.4740])
# Epoch 281 Loss: 304.03314208984375 - Pred: tensor([0.4747])
# Epoch 282 Loss: 303.6714172363281 - Pred: tensor([0.4755])
# Epoch 283 Loss: 303.308837890625 - Pred: tensor([0.4762])
# Epoch 284 Loss: 302.9453430175781 - Pred: tensor([0.4769])
# Epoch 285 Loss: 302.5809020996094 - Pred: tensor([0.4776])
# Epoch 286 Loss: 302.21551513671875 - Pred: tensor([0.4783])
# Epoch 287 Loss: 301.8489990234375 - Pred: tensor([0.4790])
# Epoch 288 Loss: 301.4814147949219 - Pred: tensor([0.4797])
# Epoch 289 Loss: 301.1124267578125 - Pred: tensor([0.4804])
# Epoch 290 Loss: 300.7421569824219 - Pred: tensor([0.4812])
# Epoch 291 Loss: 300.37078857421875 - Pred: tensor([0.4819])
# Epoch 292 Loss: 299.9987487792969 - Pred: tensor([0.4826])
# Epoch 293 Loss: 299.62567138671875 - Pred: tensor([0.4833])
# Epoch 294 Loss: 299.25067138671875 - Pred: tensor([0.4840])
# Epoch 295 Loss: 298.874267578125 - Pred: tensor([0.4847])
# Epoch 296 Loss: 298.497314453125 - Pred: tensor([0.4854])
# Epoch 297 Loss: 298.1194763183594 - Pred: tensor([0.4861])
# Epoch 298 Loss: 297.7401428222656 - Pred: tensor([0.4868])
# Epoch 299 Loss: 297.3596496582031 - Pred: tensor([0.4875])
# Epoch 300 Loss: 296.9786376953125 - Pred: tensor([0.4882])
# Epoch 301 Loss: 296.59649658203125 - Pred: tensor([0.4890])
# Epoch 302 Loss: 296.2130432128906 - Pred: tensor([0.4897])
# Epoch 303 Loss: 295.82904052734375 - Pred: tensor([0.4905])
# Epoch 304 Loss: 295.4441223144531 - Pred: tensor([0.4912])
# Epoch 305 Loss: 295.0579833984375 - Pred: tensor([0.4920])
# Epoch 306 Loss: 294.671142578125 - Pred: tensor([0.4927])
# Epoch 307 Loss: 294.28363037109375 - Pred: tensor([0.4935])
# Epoch 308 Loss: 293.89495849609375 - Pred: tensor([0.4943])
# Epoch 309 Loss: 293.50537109375 - Pred: tensor([0.4950])
# Epoch 310 Loss: 293.1151123046875 - Pred: tensor([0.4958])
# Epoch 311 Loss: 292.7238464355469 - Pred: tensor([0.4966])
# Epoch 312 Loss: 292.3316650390625 - Pred: tensor([0.4973])
# Epoch 313 Loss: 291.9387512207031 - Pred: tensor([0.4981])
# Epoch 314 Loss: 291.54486083984375 - Pred: tensor([0.4989])
# Epoch 315 Loss: 291.15008544921875 - Pred: tensor([0.4996])
# Epoch 316 Loss: 290.75457763671875 - Pred: tensor([0.5004])
# Epoch 317 Loss: 290.35821533203125 - Pred: tensor([0.5011])
# Epoch 318 Loss: 289.96099853515625 - Pred: tensor([0.5019])
# Epoch 319 Loss: 289.5631103515625 - Pred: tensor([0.5026])
# Epoch 320 Loss: 289.1643981933594 - Pred: tensor([0.5033])
# Epoch 321 Loss: 288.7648620605469 - Pred: tensor([0.5040])
# Epoch 322 Loss: 288.3646545410156 - Pred: tensor([0.5048])
# Epoch 323 Loss: 287.963623046875 - Pred: tensor([0.5055])
# Epoch 324 Loss: 287.56158447265625 - Pred: tensor([0.5062])
# Epoch 325 Loss: 287.1587829589844 - Pred: tensor([0.5069])
# Epoch 326 Loss: 286.7548828125 - Pred: tensor([0.5076])
# Epoch 327 Loss: 286.34979248046875 - Pred: tensor([0.5084])
# Epoch 328 Loss: 285.943359375 - Pred: tensor([0.5091])
# Epoch 329 Loss: 285.5352478027344 - Pred: tensor([0.5098])
# Epoch 330 Loss: 285.12493896484375 - Pred: tensor([0.5105])
# Epoch 331 Loss: 284.7122802734375 - Pred: tensor([0.5112])
# Epoch 332 Loss: 284.2974853515625 - Pred: tensor([0.5119])
# Epoch 333 Loss: 283.8807678222656 - Pred: tensor([0.5125])
# Epoch 334 Loss: 283.4620666503906 - Pred: tensor([0.5132])
# Epoch 335 Loss: 283.0423889160156 - Pred: tensor([0.5139])
# Epoch 336 Loss: 282.621826171875 - Pred: tensor([0.5146])
# Epoch 337 Loss: 282.2004089355469 - Pred: tensor([0.5152])
# Epoch 338 Loss: 281.7789306640625 - Pred: tensor([0.5159])
# Epoch 339 Loss: 281.3569030761719 - Pred: tensor([0.5166])
# Epoch 340 Loss: 280.9345703125 - Pred: tensor([0.5173])
# Epoch 341 Loss: 280.51153564453125 - Pred: tensor([0.5180])
# Epoch 342 Loss: 280.08770751953125 - Pred: tensor([0.5187])
# Epoch 343 Loss: 279.6633605957031 - Pred: tensor([0.5194])
# Epoch 344 Loss: 279.2379150390625 - Pred: tensor([0.5201])
# Epoch 345 Loss: 278.8111877441406 - Pred: tensor([0.5208])
# Epoch 346 Loss: 278.383544921875 - Pred: tensor([0.5216])
# Epoch 347 Loss: 277.9546813964844 - Pred: tensor([0.5223])
# Epoch 348 Loss: 277.5244140625 - Pred: tensor([0.5231])
# Epoch 349 Loss: 277.0932312011719 - Pred: tensor([0.5238])
# Epoch 350 Loss: 276.6613464355469 - Pred: tensor([0.5246])
# Epoch 351 Loss: 276.2286376953125 - Pred: tensor([0.5253])
# Epoch 352 Loss: 275.7958679199219 - Pred: tensor([0.5261])
# Epoch 353 Loss: 275.3629150390625 - Pred: tensor([0.5269])
# Epoch 354 Loss: 274.9300231933594 - Pred: tensor([0.5277])
# Epoch 355 Loss: 274.4975280761719 - Pred: tensor([0.5284])
# Epoch 356 Loss: 274.0654296875 - Pred: tensor([0.5292])
# Epoch 357 Loss: 273.6338195800781 - Pred: tensor([0.5300])
# Epoch 358 Loss: 273.2027282714844 - Pred: tensor([0.5308])
# Epoch 359 Loss: 272.7721862792969 - Pred: tensor([0.5316])
# Epoch 360 Loss: 272.3420715332031 - Pred: tensor([0.5324])
# Epoch 361 Loss: 271.9124755859375 - Pred: tensor([0.5333])
# Epoch 362 Loss: 271.483154296875 - Pred: tensor([0.5341])
# Epoch 363 Loss: 271.05419921875 - Pred: tensor([0.5349])
# Epoch 364 Loss: 270.62548828125 - Pred: tensor([0.5357])
# Epoch 365 Loss: 270.1969909667969 - Pred: tensor([0.5365])
# Epoch 366 Loss: 269.7686767578125 - Pred: tensor([0.5373])
# Epoch 367 Loss: 269.3404846191406 - Pred: tensor([0.5381])
# Epoch 368 Loss: 268.912353515625 - Pred: tensor([0.5389])
# Epoch 369 Loss: 268.48431396484375 - Pred: tensor([0.5398])
# Epoch 370 Loss: 268.0563049316406 - Pred: tensor([0.5406])
# Epoch 371 Loss: 267.6282653808594 - Pred: tensor([0.5414])
# Epoch 372 Loss: 267.2002258300781 - Pred: tensor([0.5422])
# Epoch 373 Loss: 266.7721862792969 - Pred: tensor([0.5430])
# Epoch 374 Loss: 266.3440856933594 - Pred: tensor([0.5438])
# Epoch 375 Loss: 265.91595458984375 - Pred: tensor([0.5446])
# Epoch 376 Loss: 265.48773193359375 - Pred: tensor([0.5454])
# Epoch 377 Loss: 265.0594787597656 - Pred: tensor([0.5462])
# Epoch 378 Loss: 264.631103515625 - Pred: tensor([0.5470])
# Epoch 379 Loss: 264.2027282714844 - Pred: tensor([0.5478])
# Epoch 380 Loss: 263.7742004394531 - Pred: tensor([0.5486])
# Epoch 381 Loss: 263.3456115722656 - Pred: tensor([0.5494])
# Epoch 382 Loss: 262.9169921875 - Pred: tensor([0.5502])
# Epoch 383 Loss: 262.4883117675781 - Pred: tensor([0.5510])
# Epoch 384 Loss: 262.05950927734375 - Pred: tensor([0.5518])
# Epoch 385 Loss: 261.6305847167969 - Pred: tensor([0.5527])
# Epoch 386 Loss: 261.20172119140625 - Pred: tensor([0.5535])
# Epoch 387 Loss: 260.7727355957031 - Pred: tensor([0.5543])
# Epoch 388 Loss: 260.3437194824219 - Pred: tensor([0.5551])
# Epoch 389 Loss: 259.9147033691406 - Pred: tensor([0.5559])
# Epoch 390 Loss: 259.4855651855469 - Pred: tensor([0.5567])
# Epoch 391 Loss: 259.0564270019531 - Pred: tensor([0.5575])
# Epoch 392 Loss: 258.6273193359375 - Pred: tensor([0.5584])
# Epoch 393 Loss: 258.1981506347656 - Pred: tensor([0.5592])
# Epoch 394 Loss: 257.76904296875 - Pred: tensor([0.5600])
# Epoch 395 Loss: 257.3399353027344 - Pred: tensor([0.5608])
# Epoch 396 Loss: 256.910888671875 - Pred: tensor([0.5616])
# Epoch 397 Loss: 256.4819030761719 - Pred: tensor([0.5624])
# Epoch 398 Loss: 256.0529479980469 - Pred: tensor([0.5633])
# Epoch 399 Loss: 255.6241455078125 - Pred: tensor([0.5641])
# Epoch 400 Loss: 255.19552612304688 - Pred: tensor([0.5649])
# Epoch 401 Loss: 254.767822265625 - Pred: tensor([0.5657])
# Epoch 402 Loss: 254.34881591796875 - Pred: tensor([0.5665])
# Epoch 403 Loss: 253.9847412109375 - Pred: tensor([0.5674])
# Epoch 404 Loss: 253.5408935546875 - Pred: tensor([0.5681])
# Epoch 405 Loss: 253.07852172851562 - Pred: tensor([0.5689])
# Epoch 406 Loss: 252.656494140625 - Pred: tensor([0.5698])
# Epoch 407 Loss: 252.2592315673828 - Pred: tensor([0.5705])
# Epoch 408 Loss: 251.82310485839844 - Pred: tensor([0.5714])
# Epoch 409 Loss: 251.3738250732422 - Pred: tensor([0.5721])
# Epoch 410 Loss: 251.02313232421875 - Pred: tensor([0.5729])
# Epoch 411 Loss: 250.5745391845703 - Pred: tensor([0.5738])
# Epoch 412 Loss: 250.1570587158203 - Pred: tensor([0.5746])
# Epoch 413 Loss: 249.71176147460938 - Pred: tensor([0.5753])
# Epoch 414 Loss: 249.29971313476562 - Pred: tensor([0.5762])
# Epoch 415 Loss: 248.88555908203125 - Pred: tensor([0.5770])
# Epoch 416 Loss: 248.4387969970703 - Pred: tensor([0.5778])
# Epoch 417 Loss: 248.0400390625 - Pred: tensor([0.5786])
# Epoch 418 Loss: 247.5927276611328 - Pred: tensor([0.5795])
# Epoch 419 Loss: 247.19313049316406 - Pred: tensor([0.5803])
# Epoch 420 Loss: 246.75311279296875 - Pred: tensor([0.5811])
# Epoch 421 Loss: 246.34732055664062 - Pred: tensor([0.5819])
# Epoch 422 Loss: 245.9253692626953 - Pred: tensor([0.5828])
# Epoch 423 Loss: 245.49600219726562 - Pred: tensor([0.5836])
# Epoch 424 Loss: 245.0902862548828 - Pred: tensor([0.5844])
# Epoch 425 Loss: 244.66452026367188 - Pred: tensor([0.5853])
# Epoch 426 Loss: 244.25599670410156 - Pred: tensor([0.5861])
# Epoch 427 Loss: 243.82701110839844 - Pred: tensor([0.5868])
# Epoch 428 Loss: 243.4206085205078 - Pred: tensor([0.5877])
# Epoch 429 Loss: 242.9969482421875 - Pred: tensor([0.5885])
# Epoch 430 Loss: 242.58767700195312 - Pred: tensor([0.5893])
# Epoch 431 Loss: 242.16627502441406 - Pred: tensor([0.5901])
# Epoch 432 Loss: 241.7561798095703 - Pred: tensor([0.5909])
# Epoch 433 Loss: 241.33941650390625 - Pred: tensor([0.5917])
# Epoch 434 Loss: 240.9239501953125 - Pred: tensor([0.5925])
# Epoch 435 Loss: 240.5149688720703 - Pred: tensor([0.5933])
# Epoch 436 Loss: 240.0938262939453 - Pred: tensor([0.5941])
# Epoch 437 Loss: 239.6908721923828 - Pred: tensor([0.5949])
# Epoch 438 Loss: 239.26947021484375 - Pred: tensor([0.5958])
# Epoch 439 Loss: 238.86181640625 - Pred: tensor([0.5966])
# Epoch 440 Loss: 238.44546508789062 - Pred: tensor([0.5974])
# Epoch 441 Loss: 238.03494262695312 - Pred: tensor([0.5982])
# Epoch 442 Loss: 237.61952209472656 - Pred: tensor([0.5990])
# Epoch 443 Loss: 237.20860290527344 - Pred: tensor([0.5998])
# Epoch 444 Loss: 236.7915802001953 - Pred: tensor([0.6007])
# Epoch 445 Loss: 236.3786163330078 - Pred: tensor([0.6015])
# Epoch 446 Loss: 235.9630126953125 - Pred: tensor([0.6023])
# Epoch 447 Loss: 235.54559326171875 - Pred: tensor([0.6031])
# Epoch 448 Loss: 235.13043212890625 - Pred: tensor([0.6039])
# Epoch 449 Loss: 234.7132568359375 - Pred: tensor([0.6046])
# Epoch 450 Loss: 234.2981414794922 - Pred: tensor([0.6054])
# Epoch 451 Loss: 233.88320922851562 - Pred: tensor([0.6062])
# Epoch 452 Loss: 233.47225952148438 - Pred: tensor([0.6070])
# Epoch 453 Loss: 233.06076049804688 - Pred: tensor([0.6078])
# Epoch 454 Loss: 232.6535186767578 - Pred: tensor([0.6086])
# Epoch 455 Loss: 232.24749755859375 - Pred: tensor([0.6094])
# Epoch 456 Loss: 231.84451293945312 - Pred: tensor([0.6103])
# Epoch 457 Loss: 231.44168090820312 - Pred: tensor([0.6111])
# Epoch 458 Loss: 231.041748046875 - Pred: tensor([0.6119])
# Epoch 459 Loss: 230.64260864257812 - Pred: tensor([0.6127])
# Epoch 460 Loss: 230.24493408203125 - Pred: tensor([0.6135])
# Epoch 461 Loss: 229.84739685058594 - Pred: tensor([0.6143])
# Epoch 462 Loss: 229.45127868652344 - Pred: tensor([0.6151])
# Epoch 463 Loss: 229.055908203125 - Pred: tensor([0.6159])
# Epoch 464 Loss: 228.6614532470703 - Pred: tensor([0.6167])
# Epoch 465 Loss: 228.26748657226562 - Pred: tensor([0.6175])
# Epoch 466 Loss: 227.87413024902344 - Pred: tensor([0.6183])
# Epoch 467 Loss: 227.48159790039062 - Pred: tensor([0.6190])
# Epoch 468 Loss: 227.0897674560547 - Pred: tensor([0.6198])
# Epoch 469 Loss: 226.69895935058594 - Pred: tensor([0.6206])
# Epoch 470 Loss: 226.3086700439453 - Pred: tensor([0.6214])
# Epoch 471 Loss: 225.91941833496094 - Pred: tensor([0.6221])
# Epoch 472 Loss: 225.53060913085938 - Pred: tensor([0.6229])
# Epoch 473 Loss: 225.1428680419922 - Pred: tensor([0.6237])
# Epoch 474 Loss: 224.75564575195312 - Pred: tensor([0.6244])
# Epoch 475 Loss: 224.36959838867188 - Pred: tensor([0.6252])
# Epoch 476 Loss: 223.984130859375 - Pred: tensor([0.6260])
# Epoch 477 Loss: 223.5997772216797 - Pred: tensor([0.6268])
# Epoch 478 Loss: 223.21621704101562 - Pred: tensor([0.6275])
# Epoch 479 Loss: 222.83383178710938 - Pred: tensor([0.6283])
# Epoch 480 Loss: 222.4528045654297 - Pred: tensor([0.6291])
# Epoch 481 Loss: 222.07403564453125 - Pred: tensor([0.6298])
# Epoch 482 Loss: 221.69927978515625 - Pred: tensor([0.6306])
# Epoch 483 Loss: 221.33404541015625 - Pred: tensor([0.6314])
# Epoch 484 Loss: 220.98394775390625 - Pred: tensor([0.6321])
# Epoch 485 Loss: 220.662109375 - Pred: tensor([0.6329])
# Epoch 486 Loss: 220.3074493408203 - Pred: tensor([0.6336])
# Epoch 487 Loss: 219.89471435546875 - Pred: tensor([0.6344])
# Epoch 488 Loss: 219.4403076171875 - Pred: tensor([0.6351])
# Epoch 489 Loss: 219.0807342529297 - Pred: tensor([0.6358])
# Epoch 490 Loss: 218.76951599121094 - Pred: tensor([0.6366])
# Epoch 491 Loss: 218.3718719482422 - Pred: tensor([0.6373])
# Epoch 492 Loss: 217.9510498046875 - Pred: tensor([0.6380])
# Epoch 493 Loss: 217.60250854492188 - Pred: tensor([0.6388])
# Epoch 494 Loss: 217.26377868652344 - Pred: tensor([0.6395])
# Epoch 495 Loss: 216.86862182617188 - Pred: tensor([0.6403])
# Epoch 496 Loss: 216.48011779785156 - Pred: tensor([0.6410])
# Epoch 497 Loss: 216.14227294921875 - Pred: tensor([0.6417])
# Epoch 498 Loss: 215.7839813232422 - Pred: tensor([0.6425])
# Epoch 499 Loss: 215.39016723632812 - Pred: tensor([0.6432])

# %%
a = pred.numpy()
b = y_data.numpy()
pred.numpy().reshape(-1).shape, y_data.numpy().shape
# Out:
# ((569,), (569,))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
c = confusion_matrix(a,b)
sns.heatmap(c, annot=True, xticklabels=le.classes_, yticklabels=le.classes_);

# %%
print(classification_report(a,b))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       371
#         True       0.88      0.94      0.91       198
#
#     accuracy                           0.93       569
#    macro avg       0.92      0.93      0.93       569
# weighted avg       0.94      0.93      0.93       569
